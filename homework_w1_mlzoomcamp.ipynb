# %%
import pandas as pd
pd.__version__
# Out:
# '1.3.4'

# %%
# !pip install wget
# Out:
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9672 sha256=ddca95cfe8b0981c00387ef14a1a262107fa06f2981117ba5aa8ced0ea0cd812
#   Stored in directory: c:\users\ksidd\appdata\local\pip\cache\wheels\04\5f\3e\46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# ...

# %%
import wget

# %%
housing = wget.download("https://raw.githubusercontent.com/alexeygrigorev/datasets/master/housing.csv")
# Out:
#  85% [...............................................................           ] 1212416 / 1423529
# 100% [..........................................................................] 1423529 / 1423529

# %%
housing_table = pd.read_csv(housing)

# %%
df = pd.DataFrame(housing_table)

# %%
df.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# ...

# %%
df.latitude[:5]
# Out:
# 0    37.88
# 1    37.86
# 2    37.85
# 3    37.85
# 4    37.85
# Name: latitude, dtype: float64

# %%
#Which columns in the dataset have missing values?
'''
total_rooms
total_bedrooms
both of the above
no empty columns in the dataset
'''

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
df['total_bedrooms']<= 10
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20635    False
# 20636    False
# 20637    False
# 20638    False
# 20639    False
# Name: total_bedrooms, Length: 20640, dtype: bool

# %%
df[df['total_bedrooms']<= 10]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 73       -122.29     37.81                46.0         12.0             4.0
# 1419     -122.05     37.97                16.0         60.0            10.0
# 1721     -122.39     38.00                33.0         44.0             6.0
# 2012     -119.83     36.72                28.0         60.0            10.0
# 2511     -119.54     36.51                36.0         49.0             7.0
# 3125     -117.76     35.22                 4.0         18.0             3.0
# 3126     -117.79     35.21                 4.0          2.0             2.0
# 3256     -120.13     35.87                26.0         48.0             8.0
# 3364     -120.51     40.41                36.0         36.0             8.0
# 4093     -118.42     34.16                46.0         54.0             9.0
# 4492     -118.22     34.06                52.0         48.0             6.0
# ...

# %%
df.median_house_value[df.ocean_proximity == 'NEAR BAY'].mean()
# Out:
# 259212.31179039303

# %%
df['total_bedrooms'].mean()
# Out:
# 537.8705525375618

# %%
df['total_bedrooms'].fillna(537.870).mean()
# Out:
# 537.8705469961225

# %%
df[['housing_median_age', 'total_rooms', 'total_bedrooms']][df.ocean_proximity == 'ISLAND']
# Out:
#       housing_median_age  total_rooms  total_bedrooms
# 8314                27.0       1675.0           521.0
# 8315                52.0       2359.0           591.0
# 8316                52.0       2127.0           512.0
# 8317                52.0        996.0           264.0
# 8318                29.0        716.0           214.0

# %%
X = df[['housing_median_age', 'total_rooms', 'total_bedrooms']][df.ocean_proximity == 'ISLAND'].value()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13288/88757140.py in <module>
# ----> 1 X = df[['housing_median_age', 'total_rooms', 'total_bedrooms']][df.ocean_proximity == 'ISLAND'].value()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value'
